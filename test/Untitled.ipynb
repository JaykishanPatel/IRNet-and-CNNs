# %%
import sys, os, time, math, argparse, numpy as np
from matplotlib import pyplot as plt
import torch, torch.nn as nn
from util import fullpath
import irnet, torch_util as tu

device = tu.device()
net = irnet.IRNet().to( device )
tu.load(model=net, device=device, filename='model-geometric-1-.pt', require=False)
net.eval()
# Out:
# running on cuda:0 (NVIDIA GeForce RTX 3080)
# loading model file model-geometric-1-.pt
# IRNet(
#   (elayers): ModuleList(
#     (0): Sequential(
#       (conv): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(32, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (1): Sequential(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(32, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (2): Sequential(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(32, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (3): Sequential(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(64, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#       (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (4): Sequential(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(64, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (5): Sequential(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(64, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (6): Sequential(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(128, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#       (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (7): Sequential(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(128, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (8): Sequential(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(128, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (9): Sequential(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(256, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#       (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (10): Sequential(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(256, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (11): Sequential(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(256, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (12): Sequential(
#       (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(512, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#       (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (13): Sequential(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(512, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (14): Sequential(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(512, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#   )
#   (alayers): ModuleList(
#     (0): Sequential(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(512, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (1): Sequential(
#       (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(512, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (2): Sequential(
#       (conv): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (batch): BatchNorm2d(256, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (3): Sequential(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(256, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (4): Sequential(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(256, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (5): Sequential(
#       (conv): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (batch): BatchNorm2d(128, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (6): Sequential(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(128, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (7): Sequential(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(128, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (8): Sequential(
#       (conv): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (batch): BatchNorm2d(64, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (9): Sequential(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(64, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (10): Sequential(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(64, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (11): Sequential(
#       (conv): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (batch): BatchNorm2d(32, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (12): Sequential(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(32, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (13): Sequential(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(32, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (14): Sequential(
#       (conv): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (askiplayers): ModuleList(
#     (0): Module()
#     (1): Module()
#     (2): Sequential(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(256, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (3): Module()
#     (4): Module()
#     (5): Sequential(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(128, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (6): Module()
#     (7): Module()
#     (8): Sequential(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(64, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (9): Module()
#     (10): Module()
#     (11): Sequential(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (batch): BatchNorm2d(32, eps=0.0001, momentum=0.1, affine=True, track_running_stats=True)
#       (act): ReLU()
#     )
#     (12): Module()
#     (13): Module()
#     (14): Module()
#   )
# )

# %%
vgen = tu.gen('images', batchsize=1, tensor=True, device=device)

# %%
for batchk, (lum_in, rg_label, filelist) in enumerate(vgen):
    print(lum_in)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
#       1 for batchk, (lum_in, rg_label, filelist) in enumerate(vgen):
# ----> 2     print(lum_in)
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor.py:305, in Tensor.__repr__(self)
#     303     return handle_torch_function(Tensor.__repr__, (self,), self)
#     304 # All strings are unicode in Python 3.
# --> 305 return torch._tensor_str._str(self)
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor_str.py:434, in _str(self)
#     432 def _str(self):
#     433     with torch.no_grad():
# --> 434         return _str_intern(self)
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor_str.py:409, in _str_intern(inp)
#     407                 tensor_str = _tensor_str(self.to_dense(), indent)
#     408             else:
# --> 409                 tensor_str = _tensor_str(self, indent)
#     411 if self.layout != torch.strided:
#     412     suffixes.append('layout=' + str(self.layout))
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor_str.py:264, in _tensor_str(self, indent)
#     262     return _tensor_str_with_formatter(self, indent, summarize, real_formatter, imag_formatter)
#     263 else:
# --> 264     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     265     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor_str.py:298, in get_summarized_data(self)
#     296     return torch.stack([get_summarized_data(x) for x in (start + end)])
#     297 else:
# --> 298     return torch.stack([get_summarized_data(x) for x in self])
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor_str.py:298, in <listcomp>(.0)
#     296     return torch.stack([get_summarized_data(x) for x in (start + end)])
#     297 else:
# --> 298     return torch.stack([get_summarized_data(x) for x in self])
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor_str.py:298, in get_summarized_data(self)
#     296     return torch.stack([get_summarized_data(x) for x in (start + end)])
#     297 else:
# --> 298     return torch.stack([get_summarized_data(x) for x in self])
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor_str.py:298, in <listcomp>(.0)
#     296     return torch.stack([get_summarized_data(x) for x in (start + end)])
#     297 else:
# --> 298     return torch.stack([get_summarized_data(x) for x in self])
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor_str.py:296, in get_summarized_data(self)
#     293     start = [self[i] for i in range(0, PRINT_OPTS.edgeitems)]
#     294     end = ([self[i]
#     295            for i in range(len(self) - PRINT_OPTS.edgeitems, len(self))])
# --> 296     return torch.stack([get_summarized_data(x) for x in (start + end)])
#     297 else:
#     298     return torch.stack([get_summarized_data(x) for x in self])
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor_str.py:296, in <listcomp>(.0)
#     293     start = [self[i] for i in range(0, PRINT_OPTS.edgeitems)]
#     294     end = ([self[i]
#     295            for i in range(len(self) - PRINT_OPTS.edgeitems, len(self))])
# --> 296     return torch.stack([get_summarized_data(x) for x in (start + end)])
#     297 else:
#     298     return torch.stack([get_summarized_data(x) for x in self])
#
# File ~/jay-work/.venv/lib/python3.8/site-packages/torch/_tensor_str.py:289, in get_summarized_data(self)
#     287 if dim == 1:
#     288     if self.size(0) > 2 * PRINT_OPTS.edgeitems:
# --> 289         return torch.cat((self[:PRINT_OPTS.edgeitems], self[-PRINT_OPTS.edgeitems:]))
#     290     else:
#     291         return self
#
# RuntimeError: CUDA error: no kernel image is available for execution on the device
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
